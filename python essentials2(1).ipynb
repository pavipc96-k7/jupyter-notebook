# %%
list_int=[2,4,54,45,67,88,8]

# %%
list_int.sort()
list_int
# Out:
# [2, 4, 8, 45, 54, 67, 88]

# %%
list_str=["b","s","c","d","a","z"]

# %%
list_str.sort()
list_str
# Out:
# ['a', 'b', 'c', 'd', 's', 'z']

# %%
list_int=[23,43,12,56,46,36,52,66,65,78,97,87]

# %%
list_int.sort(reverse= True)

# %%
list_int
# Out:
# [97, 87, 78, 66, 65, 56, 52, 46, 43, 36, 23, 12]

# %%
l1=[1,12,23,14,15]
all(l1)
# Out:
# True

# %%
any(l1)
# Out:
# True

# %%
l2=[0,12,13,14,15,16]
all(l2)
# Out:
# False

# %%
any(l2)
# Out:
# True

# %% [markdown]
# #### tuples

# %%
tup1= (1,2,3)
type(tup1)
# Out:
# tuple

# %%
tup2= (10,20,30) # tuple of integer numbers

# %%
tup3= (11.2,33.3,44.4,11.1,14.3) # tuple of float numbers

# %%
tup4= ('one','two','three','four','five') # tuple of strings

# %%
tup5= (90,24,(34,54),[56.9,87.9],'pavi') # nested tuples

# %%
tup_nsted=(1,3,5,(100,200),(999,199))

# %%
tup_nsted[3][0]
# Out:
# 100

# %%
tup5[2][1]
# Out:
# 54

# %%
tup5[4]
# Out:
# 'pavi'

# %% [markdown]
# ## tuple slicing

# %%
mytuple=('one','two','three','four','five','six','seven','eight')
mytuple[0:3] #return all items from 0th to 3rd index location excluding the upper limit
# Out:
# ('one', 'two', 'three')

# %%
mytuple1=('one','two','three')

# %% [markdown]
# ### remove and change items

# %%
del mytuple1[0] #it cannot support deletion inside the tuple because it is immutable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 del mytuple1[0] #it cannot support deletion inside the tuple because it is immutable
#
# NameError: name 'mytuple1' is not defined

# %%
mytuple1=('one','two','three')

# %%
del mytuple1 # deleting entire tuple object is possible
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 del mytuple1 # deleting entire tuple object is possible
#
# NameError: name 'mytuple1' is not defined

# %% [markdown]
# ## count

# %%
my_tuple=(1,2,3,4,1,2,4,'one','two','one')
my_tuple.count(1)
# Out:
# 2

# %%
my_tuple.index('one') # it will give the first index location
# Out:
# 7

# %% [raw]
# the replacement in the strings concept cannot be happen in tuples.

# %%
#the tuple replacement cannot be happen

# %% [markdown]
# ### tuple membership

# %%
'80' not in my_tuple # check if 'one' exist in the tuple
# Out:
# True

# %% [markdown]
# ## tuple sorting

# %%
my_tuple=(12,32,66,56,45,31)
sorted(my_tuple)
# Out:
# [12, 31, 32, 45, 56, 66]

# %%
sorted(my_tuple, reverse = True) # to sort in a descending order
# Out:
# [66, 56, 45, 32, 31, 12]

# %% [markdown]
# ## set

# %% [raw]
# 1) unordered & unindexed collection of items
# 2) set elements are unique. duplicate elements are not allowed.

# %%
my_set = {}
type(my_set)
# Out:
# dict

# %%
my_set={1,2,30,43,32}
type(my_set)
# Out:
# set

# %%
my_set_int = {12,23,34,45,56,65,43}

# %%
my_set_float={11.2,22.3,33.4,44.5,55.4}

# %%
my_set_str={'pavi','praveen','gokul','krish','girish'}

# %% [markdown]
# ### 19-08-2026

# %%
v=[0,1,2,3,[8,{5:[67,89,90,{'area':'kudlu','city':'bangalore'}]}]] ## get bangalore

# %%
v[4][1][5][3]['city']
# Out:
# 'bangalore'

# %% [markdown]
# ## add remove and change items

# %%
my_dict={'name':'data','Dept':'ID','place':'bangalore','block':'D'}

# %%
my_dict["name"]="clara"

# %%
my_dict
# Out:
# {'name': 'clara', 'Dept': 'ID', 'place': 'bangalore', 'block': 'D'}

# %%
my_dict.update({"area":"electronic city"})

# %%
my_dict
# Out:
# {'name': 'clara',
#  'Dept': 'ID',
#  'place': 'bangalore',
#  'block': 'D',
#  'area': 'electronic city'}

# %%
del my_dict["Dept"]
my_dict
# Out:
# {'name': 'clara',
#  'place': 'bangalore',
#  'block': 'c',
#  'area': 'electronic city'}

# %%
my_dict.pop("area")
# Out:
# 'electronic city'

# %%
my_dict.clear()

# %%
my_dict
# Out:
# {'name': 'clara', 'place': 'bangalore', 'block': 'c'}
