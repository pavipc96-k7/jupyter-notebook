# %% [markdown]
# ### to get the output

# %% [raw]
#    week: 1
#      day: 1
#      day: 2
#      day: 3
#    week: 2
#      day: 1
#      day: 2
#      day: 3

# %%
for i in range(1,3):
    print("week:",i)
    for j in range(1,4):
        print("day:",j)
# Out:
# week: 1
# day: 1
# day: 2
# day: 3
# week: 2
# day: 1
# day: 2
# day: 3

# %% [markdown]
# ### to get the output:

# %% [raw]
# *
# **
# ***
# ****

# %%
for
