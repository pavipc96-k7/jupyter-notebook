# %% [markdown]
# ## if-else

# %%
print("win"=="win")
# Out:
# True

# %%
print("win"=="winn")
# Out:
# False

# %%
rcb="win"
if(rcb=="win"):
    print("cup namade")
else:
    print("valakkam pola namakku cup illa")
# Out:
# cup namade

# %%
rcb="lose"
if(rcb=="win"):
    print("cup namade")
else:
    print("valakkam pola namakku cup illa")
# Out:
# valakkam pola namakku cup illa

# %%
meghna=input()
if(meghna=="died"):
    print("surya meets priya")
else:
    print("surya weds meghna")
# Out:
#  not died
# surya weds meghna

# %% [markdown]
# ### comparators

# %% [raw]
# Get input for variable mark. if mark>35 print pass. else print fail
# SAMPLE INPUT: Mark:34
# SAMPLE OUTPUT: "Fail"

# %%
mark=int(input())
if(mark>35):
    print("pass")
else:
    print("Fail")
# Out:
#  40
# pass

# %% [raw]
# 2) Get input for variable income. if income is greater than 7000 then scholarship is available. Else not eligible for scholarship
# SAMPLE INPUT: Income: 7200
# SAMPLE OUTPUT: "Not Eligible for Scholarship"

# %%
income=int(input("INCOME:"))
if(income>7000):
    print("not eligible for scholarship")
else:
    print("eligible for scholarship")
# Out:
# INCOME: 7200
# not eligible for scholarship

# %% [raw]
# 3)
# Get input for a number and check whether it is divisible by both 3 and 5 or not. if yes then print, the number is divisible by 3 and 5 else print the number is not divisible by 3 and 5.

# %%
a=int(input())
if(a%3==0 and a%5==0):
    print("divisible by both 3 and 5")
else:
    print("not divisible by 3 and 5")
# Out:
#  30
# divisible by both 3 and 5

# %% [raw]
# 4)
#
# Get input for a number and find it is even or odd.

# %%
a=int(input())
if(a%2==0):
    print("the number is even")
else:
    print("the number is odd")
# Out:
#  8
# the number is even

# %% [raw]
# 5)
#
# get input for score out of 100.
# if score<35="poor student"
# if score>35 but <70="average student"
# if score>70="good student"

# %%
score=int(input("score:"))
if(score<35):
    print("poor student")
if(score>35 and score<70):
    print("average student")
if(score>70):
    print("good student")
# Out:
# score: 78
# good student

# %%
score=int(input("score:"))
if(score<35):
    print("poor student")
elif(score>35 and score<70):
    print("average student")
else:
    print("good student")
# Out:
# score: 84
# good student

# %% [raw]
# Here, in the above given examples if the syntax or program contains only the if condition, then the program will check each and every line which contains if.
# or
# if the program contains elif, then the program will check that condition. if it is true, then the program stops then and there. and it will not check the else condition statement.

# %%
score=int(input("score:"))
if(score<35):
    print("poor student")
elif(score>35 and score<70):
    print("average student")
elif(score>70 and score<100):
    print("good student")
else:
    print("invalid number")
# Out:
# score: 101
# invalid number

# %% [raw]
# 6)
#
# Make a mini calculator
# Get input for 2 numbers a and b
# Get input from user whether to add/sub/mul/div
# If user selects add then add the two number and print the result.

# %%
a=int(input())
b=int(input())
operation= input("add/sub/mul/div:")
if(operation=="add"):
    print(a+b)
elif(operation=="sub"):
    print(a-b)
elif(operation=="mul"):
    print(a*b)
elif(operation=="div"):
    print(a/b)
else:
    print("invalid operation")
# Out:
#  20
#  30
# add/sub/mul/div: mul
# 600

# %% [raw]
# 7)
#
# Get a input for score percentage. Only if the percentage is greater than 70, get input for his name, department and location. Then print you are eligible. if not print you are not eligible.

# %%
score=int(input("enter the score:"))
if(score>=70):
    name=input("enter the name:")
    age=input("enter the age:")
    print("you are eligible")
else:
    print("you are not eligible")
# Out:
# enter the score: 72
# enter the name: pavi
# enter the age: 30
# you are eligible

# %% [raw]
# 8)
#
# Get input for salary and age.
# If salary greater than or equal to 20000 or age less than or equal to 25, get input for required loan amount. If not print you are not eligible for loan.
#
# If required loan amount is less than or equal to 50,000 print You are eligible for loan. If it is greater than 50,000 print maximum loan amount is 50000.

# %%
salary=int(input("salary:"))
age=int(input("age:"))
if(salary>=20000 or age<=25):
    print("you are eligible for loan")
    loan=int(input("loan amount:"))
    if(loan>50000):
      print("Maximum loan amount is 50000")
    else:
      print("you are eligible for loan")
else:
    print("you are not eligible for loan")
# Out:
# salary: 30000
# age: 45
# you are eligible for loan
# loan amount: 40000
# you are eligible for loan

# %% [raw]
# 9)
#
# Get input for five subjects marks. add all of it, and find average. if average mark is less than 35, print"Additional class is required" else print "you are good to go"

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
e=int(input())
f=a+b+c+d+e
average=f/5
if(average<35):
    print("additional class is required")
else:
    print("you are good to go")
# Out:
#  25
#  20
#  16
#  32
#  30
# additional class is required
