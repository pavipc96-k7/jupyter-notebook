# %% [markdown]
# # Python

# %% [markdown]
# Python is a programming language

# %% [markdown]
# **python**

# %% [markdown]
# 1. app dev
# 2. website dev
# 3. automation
# 4. ai/ml
# 5. games

# %% [raw]
# raw is used just to print text as it is

# %% [markdown]
# ### keywords in python
# keywords are reserved words in python. keywords cannot be used as an identifier.

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### identifiers
# identifier is a name given to entities like variable, functions, etc.,
#
# Rules to follow in identifier
#
# - a keyword cannot be a identifier
# - an identifier cannot start with a number
# - an identifier cannot have special symbols except underscore(_)

# %% [markdown]
# ### variables
# variables are used to store some value/data in it. variables should follow the rules of identifier. a variable is created when a value is assigned to it.

# %%
a = 50

# %%
a
# Out:
# 50

# %%
a + 50 +a
# Out:
# 150

# %%
12a = 100
# Out:
#   Cell In[7], line 1
#     12a = 100
#      ^
# SyntaxError: invalid decimal literal

# %%
import = 55
# Out:
#   Cell In[8], line 1
#     import = 55
#            ^
# SyntaxError: invalid syntax

# %%
a@b = 1000
# Out:
#   Cell In[9], line 1
#     a@b = 1000
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
num1 = 500

# %%
num1
# Out:
# 500

# %%
num2 = 19

# %% [markdown]
# num2 is not a variable until a value is assigned to it.

# %%
a = 50
b = 60
a
b
# Out:
# 60

# %% [raw]
# in this we are calling both a and b. but only b is printed. because it will only print the end or last command. to overcome this we are using print

# %%
print(a)
print(b)
# Out:
# 50
# 60

# %%
x = 10
y = 15
x = 25

# %%
x
# Out:
# 25

# %% [markdown]
# write code to store and print pincode and phone number

# %%
phno = 1234567890
pc = 560000

# %%
phno
# Out:
# 1234567890

# %%
pc
# Out:
# 560000

# %%
print(phno,pc)
# Out:
# 1234567890 560000

# %% [markdown]
# ## Data Types
# Data Type means the type of data we are storing in a variable or basically means type of data that we are handling.
#
# -  Numerical
# -  Boolean
# -  Strings

# %%
num = 10
name = 'pavi'
graduate = True

# %% [markdown]
# #### Numerical
# 1. integer (int) --> is any whole number from -infinity to +infinity but without any decimal points.
# eg: 5,10,50,0
#
# 2. float --> is any whole number from -infinity to +infinity with decimal points. eg: 14.56,3.14,9.0,8.001

# %%
a = 10
type(a)
# Out:
# int

# %%
b = 3.14
type(b)
# Out:
# float

# %% [markdown]
# #### comments in python
# comments are written to explain particular logic in the code or rarely used for documentation purpose
#
# - single line comment
# - multi line comment

# %%
a = 50 # creating a variable or assigning value to a variable

# %%
'''
following is an example for creating variable and calling a variable
'''
b = 100
b
# Out:
# 100

# %% [markdown]
# #### Boolean (bool) datatype
# it is True or False. it is output of conditional or logical operations.

# %%
50 > 10
# Out:
# True

# %%
a = True
type(a)
# Out:
# bool

# %%
b = False
type(b)
# Out:
# bool

# %% [markdown]
# #### Strings
# any character enclosed within single or double quote is called as strings

# %%
a = 'hello'

# %%
b = 'bangalore'

# %%
c = "Bangalore's food is great"
c
# Out:
# "Bangalore's food is great"

# %%
# followings are treated as string as it is enclosed within quotes
d = '1000'
e = 'true'
f = '123 is a number'

# %%
type(f)
# Out:
# str

# %%
# write code to store and print your name, location and phone
name = 'pavi'
name
# Out:
# 'pavi'

# %%
location = 'bangalore'
location
# Out:
# 'bangalore'

# %%
phone = 12345
phone
# Out:
# 12345

# %%
print(name)
print(location)
print(phone)
# Out:
# pavi
# bangalore
# 12345

# %%
x = '      ' # this is a string with atleast spaces, it is not an empty string
type(x)
# Out:
# str

# %%
y = '' # this is an empty string as there is nothing in it, not even a space
type(y)
# Out:
# str

# %% [markdown]
# #### String indexing
# it is the concept of accessing each character in the string with the help of its index value or position

# %%
X = 'GOOD MORNING'
X[0]
# Out:
# 'G'

# %%
X[3]
# Out:
# 'D'

# %%
X[7]
# Out:
# 'R'

# %%
X[9]
# Out:
# 'I'

# %%
Y = 'Data Science'
# print the following
#'D'
#'S'
#'T'
#' '
#'C'
#'N'
#'I'

# %%
Y[0],Y[5],Y[2],Y[4],Y[6],Y[9],Y[7]
# Out:
# ('D', 'S', 't', ' ', 'c', 'n', 'i')

# %%
print(Y[0])
print(Y[5])
print(Y[2])
print(Y[4])
print(Y[6])
print(Y[9])
print(Y[7])
# Out:
# D
# S
# t
#
# c
# n
# i

# %%
t = 'good afternoon'
# print the following with negative indexing
#'n'
#'f'
#'r'
#'g'
#'e'

# %%
print(t[-1],t[-8],t[-5],t[-14],t[-6])
# Out:
# n f r g e

# %% [markdown]
# #### String Slicing
# it is the concept of fetching sub string or part of the string.

# %%
x = 'data engineer'
x[0:4]
# Out:
# 'data'

# %%
x[0:4:1]
# Out:
# 'data'

# %%
x[1:3]
# Out:
# 'at'

# %%
x[5:8]
# Out:
# 'eng'

# %%
x[5:13]
# Out:
# 'engineer'

# %%
x[0:13:3]
# Out:
# 'dannr'

# %%
x[5:]
# Out:
# 'engineer'

# %%
x[:4]
# Out:
# 'data'

# %%
z = 'sky & rocket'
# print the following
#'sky'
#'rock'
#'&'
#'ket'

# %%
print(z[0:3])
print(z[6:10])
print(z[4])
print(z[9:])
# Out:
# sky
# rock
# &
# ket

# %%
e ='chairs and benches'
# print the following
#'chair'
#'air'
#'ben'
#'and'
#'enc'

# %%
print(e[0:5])
print(e[2:5])
print(e[11:14])
print(e[7:10])
print(e[-6:-3])
# Out:
# chair
# air
# ben
# and
# enc
